# %%
# !pip install ply
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# %%writefile parity_checker.py
import ply.lex as lex
import ply.yacc as yacc

# --- LEXER DEFINITION ---
tokens = ('NUMBER',)

# Regular expression for digits
t_NUMBER = r'\d+'

# Characters to ignore
t_ignore = ' \t\n'

def t_error(t):
    print(f"Illegal character '{t.value[0]}'")
    t.lexer.skip(1)

# Build the lexer
lexer = lex.lex()

# --- PARSER DEFINITION ---
def p_expr(p):
    'expr : NUMBER'
    # Convert token value to integer for logic processing
    n = int(p[1])

    # Semantic action: Parity check
    if n % 2 == 0:
        print(f"Result: {n} is Even")
    else:
        print(f"Result: {n} is Odd")

def p_error(p):
    if p:
        print(f"Syntax error at '{p.value}'")
    else:
        print("Syntax error at EOF")

# Build the parser
parser = yacc.yacc()

if __name__ == "__main__":
    # --- Execution ---
    test_input = "123"
    print(f"Input to Parser: {test_input}")
    parser.parse(test_input)
# Out:
# Writing parity_checker.py

# %%
# !python parity_checker.py
# Out:
# Generating LALR tables
# Input to Parser: 123
# Result: 123 is Odd
